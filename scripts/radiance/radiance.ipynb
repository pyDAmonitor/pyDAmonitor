# %% [markdown]
# # Satellite Radiance DA Examples

# %% [markdown]
# All scripts shown in this notebook require command-line arguments when run from a terminal or using IPython's `%run` command.

# %% [markdown]
# ## Single Instrument, Multi-Channel Time Series
#
# TODO: Support multiple observers in same plot as long as they are the same instrument (e.g. have channels from CrIS-FSR_N20 and CrIS-FSR_N21 on the same time series if requested by the user)

# %% [markdown]
# ### CrIS-FSR

# %%
# %run channel_obscount_timeseries.py --observer cris-fsr_n20 --channels 24 73 111 113 1008 --end-date "2024050623" --lookback-hours 24 --com-directory "/scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/" --exp-subdirectory "rrfs/v2.1.4/" --task-subdirectory "pyDAmonitor/" --wgf "det"
# Out:
# WARNING:root:Missing cris-fsr_n20.txt files at 6 hours:
#   2024-05-05: 23Z
#   2024-05-06: 00Z, 12Z, 21Z, 22Z, 23Z
# WARNING:root:Requested channel 24 absent from existing files at 7 hours:
#   2024-05-06: 01Z, 02Z, 03Z, 04Z, 05Z, 15Z, 16Z
# WARNING:root:Requested channel 73 absent from existing files at 7 hours:
#   2024-05-06: 01Z, 02Z, 03Z, 04Z, 05Z, 15Z, 16Z
# WARNING:root:Requested channel 111 absent from existing files at 8 hours:
#   2024-05-06: 01Z, 02Z, 03Z, 04Z, 05Z, 07Z, 15Z, 16Z
# WARNING:root:Requested channel 113 absent from existing files at 7 hours:
#   2024-05-06: 01Z, 02Z, 03Z, 04Z, 05Z, 15Z, 16Z
# WARNING:root:Requested channel 1008 absent from existing files at 9 hours:
#   2024-05-06: 01Z, 02Z, 03Z, 04Z, 05Z, 06Z, 07Z, 15Z, 16Z
# Reading files in /scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/rrfs/v2.1.4...

# %% [markdown]
# ### ATMS

# %%
# %run channel_obscount_timeseries.py --observer atms_n20 --channels 1 8 22 --end-date "2024050623" --lookback-hours 18 --com-directory "/scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/" --exp-subdirectory "rrfs/v2.1.4/" --task-subdirectory "pyDAmonitor/" --wgf "det"
# Out:
# WARNING:root:Missing atms_n20.txt files at 4 hours:
#   2024-05-06: 12Z, 21Z, 22Z, 23Z
# WARNING:root:Requested channel 1 absent from existing files at 5 hours:
#   2024-05-06: 05Z, 13Z, 14Z, 15Z, 16Z
# WARNING:root:Requested channel 8 absent from existing files at 5 hours:
#   2024-05-06: 05Z, 13Z, 14Z, 15Z, 16Z
# WARNING:root:Requested channel 22 absent from existing files at 5 hours:
#   2024-05-06: 05Z, 13Z, 14Z, 15Z, 16Z
# Reading files in /scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/rrfs/v2.1.4...

# %%
# %run channel_obscount_timeseries.py --observer atms_npp --channels 1 8 --end-date "2024050623" --lookback-hours 12 --com-directory "/scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/" --exp-subdirectory "rrfs/v2.1.4/" --task-subdirectory "pyDAmonitor/" --wgf "det"
# Out:
# WARNING:root:Missing atms_npp.txt files at 4 hours:
#   2024-05-06: 11Z, 12Z, 22Z, 23Z
# WARNING:root:Requested channel 1 absent from existing files at 3 hours:
#   2024-05-06: 14Z, 15Z, 16Z
# WARNING:root:Requested channel 8 absent from existing files at 3 hours:
#   2024-05-06: 14Z, 15Z, 16Z
# Reading files in /scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/rrfs/v2.1.4...

# %% [markdown]
# ### ABI

# %%
# %run channel_obscount_timeseries.py --observer abi_g16 --channels 8 9 10 --end-date "2024050623" --lookback-hours 24 --com-directory "/scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/" --exp-subdirectory "rrfs/v2.1.4/" --task-subdirectory "pyDAmonitor/" --wgf "det"
# Out:
# WARNING:root:Missing abi_g16.txt files at 3 hours:
#   2024-05-05: 23Z
#   2024-05-06: 00Z, 12Z
# Reading files in /scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/rrfs/v2.1.4...

# %%
# %run channel_obscount_timeseries.py --observer abi_g18 --channels 8 9 10 --end-date "2024050623" --lookback-hours 24 --com-directory "/scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/" --exp-subdirectory "rrfs/v2.1.4/" --task-subdirectory "pyDAmonitor/" --wgf "det"
# Out:
# WARNING:root:Missing abi_g18.txt files at 3 hours:
#   2024-05-05: 23Z
#   2024-05-06: 00Z, 12Z
# Reading files in /scratch4/BMC/wrfruc/Ethan.Chang/Ursa-RRFS-stuff/OPSROOT/RETRY_ALLOBSERVERS_hrly_12km/com/rrfs/v2.1.4...
